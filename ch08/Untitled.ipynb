# %%
# %pylab inline
from pandas import DataFrame,Series
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)

# %%
plt.plot(np.random.randn(50).cumsum(),)

# %%
ax1.hist(np.random.randn(100), bins=20,color='k')
# Out:
# (array([  1.,   1.,   2.,   3.,   2.,   4.,   4.,  12.,   6.,  10.,  14.,
#           9.,   7.,   6.,   8.,   3.,   4.,   2.,   1.,   1.]),
#  array([-3.20227416, -2.91256924, -2.62286431, -2.33315939, -2.04345446,
#         -1.75374954, -1.46404461, -1.17433968, -0.88463476, -0.59492983,
#         -0.30522491, -0.01551998,  0.27418494,  0.56388987,  0.8535948 ,
#          1.14329972,  1.43300465,  1.72270957,  2.0124145 ,  2.30211942,
#          2.59182435]),
#  <a list of 20 Patch objects>)

# %%
ax2.scatter(np.arange(30), np.arange(30) + 3 * randn(30))

# %%
fig

# %%
fig, ax = plt.subplots(1,1)

# %%
x = np.arange(-10, 10, 1)
y = np.sin(x)
ax.plot(x, y, 'yo--')
fig

# %%
fig = plt.figure()
fig.add_subplot(1,1,1)
